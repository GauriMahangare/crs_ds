# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
#from surprise import Reader, Dataset, SVD, evaluate

import warnings; warnings.simplefilter('ignore')

# %%
input_cleaned_file_path = '/Users/gauridhumal/Development Projects/UOL-PROJECTs/CRS/DS/crs_ds/data/processed/imdb'
output_files = '/Users/gauridhumal/Development Projects/UOL-PROJECTs/CRS/DS/crs_ds/data/processed/outputs'

# %%
def read_file(file_name):
    return pd.read_csv(open(f"{input_cleaned_file_path}/{file_name}", 'r'))

# %%
def write_file(df,file_name):
    return df.to_csv(f"{output_files}/{file_name}", index=False)

# %%
df_movie = read_file('cleaned_title_basics.csv')

# %%
df_movie.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance
# 3        0      1892      \N             12           Animation,Short
# 4        0      1893      \N              1              Comedy,Short

# %%
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10232298 entries, 0 to 10232297
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         int64
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: int64(1), object(8)
# memory usage: 702.6+ MB

# %%
df_movie_ratings=read_file('cleaned_title_ratings.csv')

# %%
df_movie_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359483 entries, 0 to 1359482
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1359483 non-null  object
#  1   averageRating  1359483 non-null  float64
#  2   numVotes       1359483 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 31.1+ MB

# %%
df_movie_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2000
# 1  tt0000002            5.8       269
# 2  tt0000003            6.5      1890
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2676

# %% [markdown]
# # Top Movies Chart

# %% [markdown]
# IMDB's weighted rating formula as below -
#
# ![image.png](attachment:image.png)
#
# The next step is to determine an appropriate value for m, the minimum votes required to be listed in the chart. We will use 95th percentile as our cutoff. In other words, for a movie to feature in the charts, it must have more votes than at least 95% of the movies in the list.

# %%
# Mean Votes across the whole report
C = df_movie_ratings['averageRating'].mean()
C
# Out:
# 6.958241405004698

# %%
# Minimum votes required to be listed in the chart
m = df_movie_ratings['numVotes'].quantile(0.95)
m
# Out:
# 1337.0

# %%
df_qualified_movies = df_movie_ratings[(df_movie_ratings['numVotes'] >= m)]

# %%
df_qualified_movies.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2000
# 2  tt0000003            6.5      1890
# 4  tt0000005            6.2      2676
# 7  tt0000008            5.4      2144
# 9  tt0000010            6.9      7318

# %%
df_qualified_movies.shape
# Out:
# (67991, 3)

# %%
# Calculate weighted rating
def weighted_rating(x):
    v = x['numVotes']
    R = x['averageRating']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
# Calculate weighted rating for qualified movies
df_qualified_movies['weighted_rating'] = df_qualified_movies.apply(weighted_rating, axis=1)

# %%
df_qualified_movies.head()
# Out:
#       tconst  averageRating  numVotes  weighted_rating
# 0  tt0000001            5.7      2000         6.204126
# 2  tt0000003            6.5      1890         6.689857
# 4  tt0000005            6.2      2676         6.452621
# 7  tt0000008            5.4      2144         5.998497
# 9  tt0000010            6.9      7318         6.908997

# %%
df_qualified_movies.shape
# Out:
# (67991, 4)

# %%
df_qualified_movies = df_qualified_movies.sort_values('weighted_rating', ascending=False)

# %%
df_qualified_movies
# Out:
#              tconst  averageRating  numVotes  weighted_rating
# 905942    tt2301451           10.0    206716         9.980453
# 1081275   tt4283088            9.9    219980         9.882229
# 1081277   tt4283094            9.9    156575         9.875093
# 905944    tt2301455            9.9    134152         9.870971
# 879356    tt2178784            9.9    114188         9.865954
# ...             ...            ...       ...              ...
# 1187874   tt6038600            1.2     40081         1.385880
# 1281174   tt7886848            1.2     96477         1.278708
# 1250592   tt7221896            1.0     39243         1.196308
# 968041   tt27528139            1.1     82015         1.193969
# 1184619   tt5988370            1.0     73927         1.105843
#
# [67991 rows x 4 columns]

# %%
df_movie[df_movie['tconst'] == 'tt2301451']
# Out:
#             tconst  titleType primaryTitle originalTitle  isAdult startYear  \
# 5859300  tt2301451  tvEpisode   Ozymandias    Ozymandias        0      2013
#
#         endYear runtimeMinutes                genres
# 5859300      \N             47  Crime,Drama,Thriller

# %% [markdown]
# ## Combine movies and movie ratings

# %%
# Join the top trending movies wiht the movie basics to get other details.
df_qualified_movies = df_qualified_movies.set_index('tconst').join(df_movie.set_index('tconst'),lsuffix='_qualified', rsuffix='_movie')

# %%
df_qualified_movies['tconst'] = df_qualified_movies.index

# %%
df_qualified_movies.shape
# Out:
# (67991, 12)

# %%
df_qualified_movies.head(10)
# Out:
#             averageRating  numVotes  weighted_rating  titleType  \
# tconst
# tt2301451            10.0    206716         9.980453  tvEpisode
# tt4283088             9.9    219980         9.882229  tvEpisode
# tt4283094             9.9    156575         9.875093  tvEpisode
# tt2301455             9.9    134152         9.870971  tvEpisode
# tt2178784             9.9    114188         9.865954  tvEpisode
# tt1683088             9.9     71313         9.845862  tvEpisode
# tt12187040            9.9     53757         9.828611  tvEpisode
# tt21151974            9.9     33321         9.786516  tvEpisode
# tt8084176             9.9     32899         9.785117  tvEpisode
# tt9906260             9.8    114999         9.767341  tvEpisode
#
#                                  primaryTitle  \
# tconst
# tt2301451                          Ozymandias
# tt4283088              Battle of the Bastards
# tt4283094                 The Winds of Winter
# tt2301455                              Felina
# tt2178784              The Rains of Castamere
# tt1683088                            Face Off
# tt12187040                 Plan and Execution
# tt21151974                   Connor's Wedding
# tt8084176   407 Proxy Authentication Required
# tt9906260                                Hero
#
#                                 originalTitle  isAdult startYear endYear  \
# tconst
# tt2301451                          Ozymandias        0      2013      \N
# tt4283088              Battle of the Bastards        0      2016      \N
# tt4283094                 The Winds of Winter        0      2016      \N
# tt2301455                              Felina        0      2013      \N
# tt2178784              The Rains of Castamere        0      2013      \N
# tt1683088                            Face Off        0      2011      \N
# tt12187040                 Plan and Execution        0      2022      \N
# tt21151974                   Connor's Wedding        0      2023      \N
# tt8084176   407 Proxy Authentication Required        0      2019      \N
# tt9906260                                Hero        0      2019      \N
#
#            runtimeMinutes                      genres      tconst
# tconst
# tt2301451              47        Crime,Drama,Thriller   tt2301451
# tt4283088              60      Action,Adventure,Drama   tt4283088
# tt4283094              68      Action,Adventure,Drama   tt4283094
# tt2301455              55        Crime,Drama,Thriller   tt2301455
# tt2178784              51      Action,Adventure,Drama   tt2178784
# tt1683088              50        Crime,Drama,Thriller   tt1683088
# tt12187040             50                 Crime,Drama  tt12187040
# tt21151974             62                Comedy,Drama  tt21151974
# tt8084176              56        Crime,Drama,Thriller   tt8084176
# tt9906260              24  Action,Adventure,Animation   tt9906260

# %%
df_qualified_movies['titleType'].value_counts()
# Out:
# titleType
# movie           35085
# tvEpisode       19289
# tvSeries         6900
# tvMovie          1883
# tvMiniSeries     1481
# video            1111
# short            1055
# videoGame         794
# tvSpecial         340
# tvShort            53
# Name: count, dtype: int64

# %% [markdown]
# ## Save Top trending content

# %%
## Save Top trending content
write_file(df_qualified_movies,'top_trending_content.csv')

# %%
df_qualified_movies_movie = df_qualified_movies[df_qualified_movies['titleType']=='movie']

# %%
# Top 20 movies
df_qualified_movies_movie.head(20)
# Out:
#             averageRating  numVotes  weighted_rating titleType  \
# tconst
# tt28145495            9.8      8230         9.402861     movie
# tt0111161             9.3   2807661         9.298885     movie
# tt16747572            9.5     10455         9.211810     movie
# tt0068646             9.2   1956575         9.198469     movie
# tt0252487             9.2     42252         9.131239     movie
# tt2592910             9.1     46894         9.040629     movie
# tt0468569             9.0   2789410         8.999022     movie
# tt0167260             9.0   1921917         8.998581     movie
# tt0108052             9.0   1411437         8.998068     movie
# tt0071562             9.0   1328624         8.997947     movie
# tt0050083             9.0    835654         8.996739     movie
# tt0259534             9.2     13042         8.991555     movie
# tt5354160             9.0     29124         8.910383     movie
# tt0110912             8.9   2153249         8.898795     movie
# tt11989890            8.9     33752         8.826013     movie
# tt17592606            9.0     13435         8.815202     movie
# tt1375666             8.8   2475755         8.799006     movie
# tt0137523             8.8   2241993         8.798902     movie
# tt0109830             8.8   2185546         8.798874     movie
# tt0120737             8.8   1950212         8.798738     movie
#
#                                                  primaryTitle  \
# tconst
# tt28145495                                        Uruttu Tech
# tt0111161                            The Shawshank Redemption
# tt16747572                            The Silence of Swastika
# tt0068646                                       The Godfather
# tt0252487                                     The Chaos Class
# tt2592910                              CM101MMXI Fundamentals
# tt0468569                                     The Dark Knight
# tt0167260       The Lord of the Rings: The Return of the King
# tt0108052                                    Schindler's List
# tt0071562                               The Godfather Part II
# tt0050083                                        12 Angry Men
# tt0259534                 Ramayana: The Legend of Prince Rama
# tt5354160                                         Mirror Game
# tt0110912                                        Pulp Fiction
# tt11989890           David Attenborough: A Life on Our Planet
# tt17592606                                              Daman
# tt1375666                                           Inception
# tt0137523                                          Fight Club
# tt0109830                                        Forrest Gump
# tt0120737   The Lord of the Rings: The Fellowship of the Ring
#
#                                                 originalTitle  isAdult  \
# tconst
# tt28145495                                        Uruttu Tech        0
# tt0111161                            The Shawshank Redemption        0
# tt16747572                            The Silence of Swastika        0
# tt0068646                                       The Godfather        0
# tt0252487                                      Hababam Sinifi        0
# tt2592910                              CM101MMXI Fundamentals        0
# tt0468569                                     The Dark Knight        0
# tt0167260       The Lord of the Rings: The Return of the King        0
# tt0108052                                    Schindler's List        0
# tt0071562                               The Godfather Part II        0
# tt0050083                                        12 Angry Men        0
# tt0259534                 Ramayana: The Legend of Prince Rama        0
# tt5354160                                            Aynabaji        0
# tt0110912                                        Pulp Fiction        0
# tt11989890           David Attenborough: A Life on Our Planet        0
# tt17592606                                              DAMaN        0
# tt1375666                                           Inception        0
# tt0137523                                          Fight Club        0
# tt0109830                                        Forrest Gump        0
# tt0120737   The Lord of the Rings: The Fellowship of the Ring        0
#
#            startYear endYear runtimeMinutes                      genres  \
# tconst
# tt28145495      2023      \N             66                      Comedy
# tt0111161       1994      \N            142                       Drama
# tt16747572      2021      \N             56         Documentary,History
# tt0068646       1972      \N            175                 Crime,Drama
# tt0252487       1975      \N             87                Comedy,Drama
# tt2592910       2013      \N            139          Comedy,Documentary
# tt0468569       2008      \N            152          Action,Crime,Drama
# tt0167260       2003      \N            201      Action,Adventure,Drama
# tt0108052       1993      \N            195     Biography,Drama,History
# tt0071562       1974      \N            202                 Crime,Drama
# tt0050083       1957      \N             96                 Crime,Drama
# tt0259534       1993      \N            135  Action,Adventure,Animation
# tt5354160       2016      \N            147      Crime,Mystery,Thriller
# tt0110912       1994      \N            154                 Crime,Drama
# tt11989890      2020      \N             83       Biography,Documentary
# tt17592606      2022      \N            121             Adventure,Drama
# tt1375666       2010      \N            148     Action,Adventure,Sci-Fi
# tt0137523       1999      \N            139                       Drama
# tt0109830       1994      \N            142               Drama,Romance
# tt0120737       2001      \N            178      Action,Adventure,Drama
#
#                 tconst
# tconst
# tt28145495  tt28145495
# tt0111161    tt0111161
# tt16747572  tt16747572
# tt0068646    tt0068646
# tt0252487    tt0252487
# tt2592910    tt2592910
# tt0468569    tt0468569
# tt0167260    tt0167260
# tt0108052    tt0108052
# tt0071562    tt0071562
# tt0050083    tt0050083
# tt0259534    tt0259534
# tt5354160    tt5354160
# tt0110912    tt0110912
# tt11989890  tt11989890
# tt17592606  tt17592606
# tt1375666    tt1375666
# tt0137523    tt0137523
# tt0109830    tt0109830
# tt0120737    tt0120737

# %%
# Top 20 TV series
df_qualified_movies_tvseries = df_qualified_movies[df_qualified_movies['titleType']=='tvSeries']

# %%
# Top 20 TV series that are thriller
df_qualified_movies_tvseries[df_qualified_movies_tvseries['genres'].str.contains('Thriller')].head(20)
# Out:
#             averageRating  numVotes  weighted_rating titleType  \
# tconst
# tt0903747             9.5   2048283         9.498342  tvSeries
# tt0306414             9.3    363013         9.291407  tvSeries
# tt2802850             8.9    390401         8.893373  tvSeries
# tt7450814             9.0     17751         8.856987  tvSeries
# tt6108262             8.9     12008         8.705460  tvSeries
# tt0118421             8.7    104185         8.677931  tvSeries
# tt0286486             8.7     85425         8.673160  tvSeries
# tt1534360             8.7     35550         8.636869  tvSeries
# tt12714854            8.7     29761         8.625116  tvSeries
# tt1124373             8.6    314034         8.593040  tvSeries
# tt1733785             8.6     74105         8.570904  tvSeries
# tt2049116             8.6     42808         8.550277  tvSeries
# tt11854694            8.6     36165         8.541469  tvSeries
# tt4063800             8.7     13303         8.540934  tvSeries
# tt4269716             8.7     11094         8.512667  tvSeries
# tt2433738             8.6     23740         8.512468  tvSeries
# tt4158110             8.5    407047         8.494952  tvSeries
# tt5071412             8.5    334122         8.493855  tvSeries
# tt15516446            8.8      6695         8.493422  tvSeries
# tt3428912             8.5     60560         8.466697  tvSeries
#
#                primaryTitle           originalTitle  isAdult startYear  \
# tconst
# tt0903747      Breaking Bad            Breaking Bad        0      2008
# tt0306414          The Wire                The Wire        0      2002
# tt2802850             Fargo                   Fargo        0      2014
# tt7450814          Koombiyo                Koombiyo        0      2017
# tt6108262         Black Sun      Senke nad Balkanom        0      2017
# tt0118421                Oz                      Oz        0      1997
# tt0286486        The Shield              The Shield        0      2002
# tt1534360              Ezel                    Ezel        0      2009
# tt12714854   Mumbai Diaries          Mumbai Diaries        0      2021
# tt1124373   Sons of Anarchy         Sons of Anarchy        0      2008
# tt1733785        The Bridge              Bron/Broen        0      2011
# tt2049116          Gomorrah       Gomorra: La serie        0      2014
# tt11854694      Special OPS             Special OPS        0      2020
# tt4063800        The Bureau  Le Bureau des Légendes        0      2015
# tt4269716             Umbre                   Umbre        0      2014
# tt2433738         Wentworth               Wentworth        0      2013
# tt4158110         Mr. Robot               Mr. Robot        0      2015
# tt5071412             Ozark                   Ozark        0      2017
# tt15516446     Matsya Kaand            Matsya Kaand        0      2021
# tt3428912      Happy Valley            Happy Valley        0      2014
#
#            endYear runtimeMinutes                  genres      tconst
# tconst
# tt0903747     2013             49    Crime,Drama,Thriller   tt0903747
# tt0306414     2008             59    Crime,Drama,Thriller   tt0306414
# tt2802850     2024             53    Crime,Drama,Thriller   tt2802850
# tt7450814     2018             20    Crime,Drama,Thriller   tt7450814
# tt6108262       \N             60    Crime,Drama,Thriller   tt6108262
# tt0118421     2003             55    Crime,Drama,Thriller   tt0118421
# tt0286486     2008             47    Crime,Drama,Thriller   tt0286486
# tt1534360     2011             90    Crime,Drama,Thriller   tt1534360
# tt12714854      \N             \N          Drama,Thriller  tt12714854
# tt1124373     2014             45    Crime,Drama,Thriller   tt1124373
# tt1733785     2018             60  Crime,Mystery,Thriller   tt1733785
# tt2049116     2021             55    Crime,Drama,Thriller   tt2049116
# tt11854694      \N             49   Action,Crime,Thriller  tt11854694
# tt4063800       \N             52          Drama,Thriller   tt4063800
# tt4269716     2019             45    Crime,Drama,Thriller   tt4269716
# tt2433738     2021             45    Crime,Drama,Thriller   tt2433738
# tt4158110     2019             49    Crime,Drama,Thriller   tt4158110
# tt5071412     2022             60    Crime,Drama,Thriller   tt5071412
# tt15516446    2021             \N                Thriller  tt15516446
# tt3428912     2023             58    Crime,Drama,Thriller   tt3428912

# %%
# Function for selecting top trending content by title type
def top_trending_title_type(df,title_type):
    return df[df['titleType'] == title_type]

# %%
# Function for selecting top trending content by genres
def top_trending_genres(df,genres):
    return df[df['genres'].str.contains(genres)]

# %%
top_trending_genres(top_trending_title_type(df_qualified_movies,'movie'),'Thriller').head(20)
# Out:
#             averageRating  numVotes  weighted_rating titleType  \
# tconst
# tt5354160             9.0     29124         8.910383     movie
# tt6019206             8.8     15105         8.650235     movie
# tt0102926             8.6   1499158         8.598537     movie
# tt23647024            9.5      2134         8.520936     movie
# tt0407887             8.5   1383942         8.498512     movie
# tt6751668             8.5    893615         8.497697     movie
# tt0054215             8.5    700909         8.497065     movie
# tt0047396             8.5    510284         8.495971     movie
# tt0058625             8.5     21757         8.410742     movie
# tt0054407             8.5     19538         8.401254     movie
# tt1345836             8.4   1780898         8.398918     movie
# tt7286456             8.4   1408959         8.398633     movie
# tt0209144             8.4   1290497         8.398508     movie
# tt0405094             8.4    402204         8.395223     movie
# tt0291855             8.7      6097         8.386746     movie
# tt0091251             8.4     90622         8.379038     movie
# tt12361178            8.4     39790         8.353130     movie
# tt4991384             8.5     11634         8.341082     movie
# tt0419781             8.6      6710         8.327224     movie
# tt4987556             8.4     21080         8.314010     movie
#
#                                   primaryTitle  \
# tconst
# tt5354160                          Mirror Game
# tt6019206   Kill Bill: The Whole Bloody Affair
# tt0102926             The Silence of the Lambs
# tt23647024                       Ap04ramapuram
# tt0407887                         The Departed
# tt6751668                             Parasite
# tt0054215                               Psycho
# tt0047396                          Rear Window
# tt0058625                   Woman in the Dunes
# tt0054407                             The Hole
# tt1345836                The Dark Knight Rises
# tt7286456                                Joker
# tt0209144                              Memento
# tt0405094                  The Lives of Others
# tt0291855                            Devasuram
# tt0091251                         Come and See
# tt12361178                          Drishyam 2
# tt4991384                           Visaaranai
# tt0419781                           Graves End
# tt4987556                         Thani Oruvan
#
#                                  originalTitle  isAdult startYear endYear  \
# tconst
# tt5354160                             Aynabaji        0      2016      \N
# tt6019206   Kill Bill: The Whole Bloody Affair        0      2006      \N
# tt0102926             The Silence of the Lambs        0      1991      \N
# tt23647024                       Ap04ramapuram        0      2022      \N
# tt0407887                         The Departed        0      2006      \N
# tt6751668                         Gisaengchung        0      2019      \N
# tt0054215                               Psycho        0      1960      \N
# tt0047396                          Rear Window        0      1954      \N
# tt0058625                         Suna no onna        0      1964      \N
# tt0054407                              Le trou        0      1960      \N
# tt1345836                The Dark Knight Rises        0      2012      \N
# tt7286456                                Joker        0      2019      \N
# tt0209144                              Memento        0      2000      \N
# tt0405094                Das Leben der Anderen        0      2006      \N
# tt0291855                            Devasuram        0      1993      \N
# tt0091251                         Idi i smotri        0      1985      \N
# tt12361178                          Drishyam 2        0      2021      \N
# tt4991384                           Visaaranai        0      2015      \N
# tt0419781                           Graves End        0      2005      \N
# tt4987556                         Thani Oruvan        0      2015      \N
#
#            runtimeMinutes                   genres      tconst
# tconst
# tt5354160             147   Crime,Mystery,Thriller   tt5354160
# tt6019206             247    Action,Crime,Thriller   tt6019206
# tt0102926             118     Crime,Drama,Thriller   tt0102926
# tt23647024            144           Drama,Thriller  tt23647024
# tt0407887             151     Crime,Drama,Thriller   tt0407887
# tt6751668             132           Drama,Thriller   tt6751668
# tt0054215             109  Horror,Mystery,Thriller   tt0054215
# tt0047396             112         Mystery,Thriller   tt0047396
# tt0058625             147           Drama,Thriller   tt0058625
# tt0054407             131     Crime,Drama,Thriller   tt0054407
# tt1345836             164    Action,Drama,Thriller   tt1345836
# tt7286456             122     Crime,Drama,Thriller   tt7286456
# tt0209144             113         Mystery,Thriller   tt0209144
# tt0405094             137   Drama,Mystery,Thriller   tt0405094
# tt0291855             187    Action,Drama,Thriller   tt0291855
# tt0091251             142       Drama,Thriller,War   tt0091251
# tt12361178            152     Crime,Drama,Thriller  tt12361178
# tt4991384             117     Crime,Drama,Thriller   tt4991384
# tt0419781              90         Mystery,Thriller   tt0419781
# tt4987556             160    Action,Crime,Thriller   tt4987556
